# %% [markdown]
# <a href="https://colab.research.google.com/github/SpaceSapiens/Code-Explorer/blob/IITM_Course/MLT_GrPA_PPA_Wk5_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week5**

# %% [markdown]
# Wk5 PPA1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
def cross_entropy(y,sigmoid_vector,w, reg_type,reg_rate):
    #print(y)
    #print(reg_type)
    reg=0
    Loss_without_reg=-1*(np.sum(y*np.log(sigmoid_vector)+(1-y)*np.log(1-sigmoid_vector)))
    #print(Loss_without_reg)
    if reg_type == 'l1':
        reg = (reg_rate/2)* np.sum(np.abs(w))
    else:
        reg = (reg_rate/2)* (np.transpose(w)@w)
    #print(reg)
    loss=Loss_without_reg+reg
    return loss

# %% [markdown]
# Wk5 PPA2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
def sigmoid(X):
  sig = 1/(1+np.exp(-X))
  return sig

# %% [markdown]
# Wk5 PPA3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
def predict_label(x,w):  
  y_hat = 1/(1+np.exp(-(X @ w)))
  labels=[]
  # compute label of the sample
  for y in y_hat:
    if y<=0.25:
      label=-1
    elif y>=0.75:
      label=1
    else:
      label=0
    labels.append(label)
  return np.array(labels)
